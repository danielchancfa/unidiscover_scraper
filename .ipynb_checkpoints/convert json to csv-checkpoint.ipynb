# %%
import json
import pandas as pd

# %%
data_list = []
with open('course_data_40page.json', 'r') as f:
    data_json = json.load(f)

# %%
df = pd.read_json('course_data_40page.json')

# %%
dfs = []

# Iterate through the JSON entries and create DataFrames
for entry in data_json:
    courseidentifier = entry["courseidentifier"]
    uniname = entry["uniname"]
    uniid = entry["uniid"]
    coursename = entry["coursename"]
    link = entry["link"]
    course_name = entry["course_name"]
    Study_mode = entry["Study mode"]
    Distance_learning = entry["Distance learning"]
    Placement_year = entry["Placement year"]
    Year_abroad = entry["Year abroad"]
    Foundation_year = entry["Foundation year"]
    
    df_dict = {
                    "courseidentifier": courseidentifier,
                    "uniname": uniname,
                    "uniid": uniid,
                    "coursename": coursename,
                    "link": link,
                    "course_name": course_name,
                    "Study mode": Study_mode,
                    "Distance learning": Distance_learning,
                    "Placement year": Placement_year,
                    "Year abroad": Year_abroad,
                    "Foundation year": Foundation_year
                }
    if 'Length' in entry.keys():
        df_dict.update({'Length':entry['Length']})
    else:
        df_dict.update({'Length':''})
        
    #Earning
    for idx, earning_item in enumerate(entry["earning"]):
        for subject, subject_data in earning_item.items():
            
            df_dict.update({f'subject{idx+1}_subject':subject})
            
            for time_period, time_data in subject_data.items():
                for k, v in time_data.items():
                    df_dict.update({f'subject{idx+1}_{time_period}_{k}'.replace(' ','_').lower():v.strip('\n')})
    #Employment                
    for idx, employment_item in enumerate(entry['employment']):
        for subject, subject_data in employment_item.items():
            for k, v in subject_data.items():
                df_dict.update({f'subject{idx+1}_{k}'.replace(' ','_').replace('-','_').lower():v.strip('\n')})
    
    #occuption
    for idx, occuption_items in enumerate(entry['occuption']):
        for occuption_c,  occuption_item in enumerate(occuption_items.items()):
            df_dict.update({f'subject{idx+1}_occuption_{occuption_item[0]}'.replace(' ','_').replace('-','_').replace(',','').lower():occuption_item[1]})
    
    df = pd.DataFrame([df_dict])
    dfs.append(df)

# Concatenate all DataFrames into one
final_df = pd.concat(dfs, ignore_index=True)

# Display the resulting DataFrame

# %%
final_df.to_csv('discover_uni(1).csv')

# %%
final_df.shape
# Out:
# (33368, 284)

# %%
final_df.head()
# Out:
#                          courseidentifier                    uniname  \
# 0  10008071/AAUNDERRADUATE5YEAR/Full-time  AA School of Architecture
# 1                 10007783/LV61/Full-time     University of Aberdeen
# 2                 10007783/LV65/Full-time     University of Aberdeen
# 3                 10007783/LR61/Full-time     University of Aberdeen
# 4                 10007783/LQ65/Full-time     University of Aberdeen
#
#       uniid                             coursename  \
# 0  10008071                     MArch Architecture
# 1  10007783     MA (Hons) Anthropology and History
# 2  10007783  MA (Hons) Anthropology and Philosophy
# 3  10007783      MA (Hons) Anthropology and French
# 4  10007783      MA (Hons) Anthropology and Gaelic
#
#                                                 link  \
# 0  /course-details/10008071/AAUNDERRADUATE5YEAR/F...
# 1            /course-details/10007783/LV61/Full-time
# 2            /course-details/10007783/LV65/Full-time
# 3            /course-details/10007783/LR61/Full-time
# 4            /course-details/10007783/LQ65/Full-time
#
#                              course_name Study mode Distance learning  \
# 0                     MArch Architecture  Full time     Not Available
# 1     MA (Hons) Anthropology and History  Full time     Not Available
# 2  MA (Hons) Anthropology and Philosophy  Full time     Not Available
# 3      MA (Hons) Anthropology and French  Full time     Not Available
# 4      MA (Hons) Anthropology and Gaelic  Full time     Not Available
#
#   Placement year    Year abroad  ...  \
# 0  Not Available  Not Available  ...
# 1  Not Available       Optional  ...
# 2  Not Available       Optional  ...
# 3  Not Available     Compulsory  ...
# 4  Not Available       Optional  ...
#
#   subject5_occuption__artistic_literary_and_media_occupations  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   subject5_occuption__secretarial_and_related_occupations  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   subject3_occuption__health_associate_professionals  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   subject3_occuption__animal_care_and_control_services  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   subject3_occuption__medical_practitioners  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   subject4_occuption__sports_and_fitness_occupations  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   subject4_occuption__welfare_and_housing_associate_professionals  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   subject4_occuption__teaching_and_childcare_support_occupation  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   subject4_occuption__leisure_travel_and_related_personal_service_occupations  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   subject4_occuption__customer_service_occupations
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
# [5 rows x 284 columns]
